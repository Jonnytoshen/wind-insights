# %%
import numpy_financial as npf
# 定义现金流：初始投资 100 万，后续 4 年收益分别为 20, 30, 40, 50
cash_flows = [-1042.42, 255.86, 275.61, 284.11, 260.30, 273.41, 226.66, 175.44, 182.95, 190.46, 197.96, 201.71, 209.22, 216.73, 224.23, 231.74, 501.28, 499.30, 497.31, 495.33, 493.35, 455.53, 453.55, 451.56, 449.58, 686.50]

irr = npf.irr(cash_flows)
print(f"该项目的 IRR 为: {irr:.2%}")
# Out:
# 该项目的 IRR 为: 24.47%

# %%
import numpy_financial as npf

rate = 0.065
cash_flows = [-207349.18, 19694.33, 20261.33, 20261.33, 20261.33, 20261.33, 20261.33, 19326.83, 18595.39, 16443.28, 16443.28, 16443.28, 15508.78, 15508.78, 15508.78, 15508.78, 15508.78, 14574.27, 14574.27, 14574.27, 25586.58] # 包含第0期
npv = npf.npv(rate, cash_flows)

print(f"该项目的 NPV 为: {npv:.2f}")
# Out:
# 该项目的 NPV 为: -6216.94
